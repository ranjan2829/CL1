# %% [markdown]
# # Assignment 8
# Analyzing Weather Data from OpenWeatherMap API

# %%
! pip install requests
# Out:
# Requirement already satisfied: requests in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from requests) (2024.8.30)

# %%
import requests
import pandas as pd
import datetime
# Set your OpenWeatherMap API key
api_key = '39971a16bbe0ea66ad553aca60155735'

# %%
lat = 18.184135
lon = 74.610764
#https://openweathermap.org/api/one-call-3#how How to use api call
# Construct the API URL
api_url = f"http://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={api_key}"
# Send a GET request to the API
response = requests.get(api_url)
weather_data = response.json() #pass response to weather_data object(dictionary)
weather_data.keys()

dict_keys=(['cod', 'message', 'cnt', 'list', 'city'])

weather_data
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1726585200,
#    'main': {'temp': 301.47,
#     'feels_like': 301.33,
#     'temp_min': 298.19,
#     'temp_max': 301.47,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 946,
#     'humidity': 43,
#     'temp_kf': 3.28},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 65},
#    'wind': {'speed': 7.68, 'deg': 287, 'gust': 9.82},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-17 15:00:00'},
#   {'dt': 1726596000,
#    'main': {'temp': 298.73,
#     'feels_like': 298.86,
#     'temp_min': 296.54,
#     'temp_max': 298.73,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 946,
#     'humidity': 58,
#     'temp_kf': 2.19},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 72},
#    'wind': {'speed': 5.92, 'deg': 289, 'gust': 10.09},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-17 18:00:00'},
#   {'dt': 1726606800,
#    'main': {'temp': 295.48,
#     'feels_like': 295.7,
#     'temp_min': 295.48,
#     'temp_max': 295.48,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 945,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 88},
#    'wind': {'speed': 4.11, 'deg': 293, 'gust': 8.56},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-17 21:00:00'},
#   {'dt': 1726617600,
#    'main': {'temp': 294.48,
#     'feels_like': 294.71,
#     'temp_min': 294.48,
#     'temp_max': 294.48,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 945,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 3.32, 'deg': 293, 'gust': 6.83},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-18 00:00:00'},
#   {'dt': 1726628400,
#    'main': {'temp': 297.25,
#     'feels_like': 297.36,
#     'temp_min': 297.25,
#     'temp_max': 297.25,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 947,
#     'humidity': 63,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 45},
#    'wind': {'speed': 4.29, 'deg': 294, 'gust': 4.96},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-18 03:00:00'},
#   {'dt': 1726639200,
#    'main': {'temp': 302.18,
#     'feels_like': 301.53,
#     'temp_min': 302.18,
#     'temp_max': 302.18,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 946,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 26},
#    'wind': {'speed': 2.73, 'deg': 296, 'gust': 2.73},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-18 06:00:00'},
#   {'dt': 1726650000,
#    'main': {'temp': 304.87,
#     'feels_like': 303.55,
#     'temp_min': 304.87,
#     'temp_max': 304.87,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 943,
#     'humidity': 29,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 3.48, 'deg': 295, 'gust': 3.22},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-18 09:00:00'},
#   {'dt': 1726660800,
#    'main': {'temp': 304.36,
#     'feels_like': 303.01,
#     'temp_min': 304.36,
#     'temp_max': 304.36,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 943,
#     'humidity': 29,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 5.76, 'deg': 301, 'gust': 3.85},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-18 12:00:00'},
#   {'dt': 1726671600,
#    'main': {'temp': 298.98,
#     'feels_like': 299.21,
#     'temp_min': 298.98,
#     'temp_max': 298.98,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 945,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 7, 'deg': 290, 'gust': 9.19},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-18 15:00:00'},
#   {'dt': 1726682400,
#    'main': {'temp': 296.85,
#     'feels_like': 297.16,
#     'temp_min': 296.85,
#     'temp_max': 296.85,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 946,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 4.51, 'deg': 285, 'gust': 6.72},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-18 18:00:00'},
#   {'dt': 1726693200,
#    'main': {'temp': 295.44,
#     'feels_like': 295.76,
#     'temp_min': 295.44,
#     'temp_max': 295.44,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 945,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 3.73, 'deg': 311, 'gust': 5.75},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-18 21:00:00'},
#   {'dt': 1726704000,
#    'main': {'temp': 294.67,
#     'feels_like': 294.97,
#     'temp_min': 294.67,
#     'temp_max': 294.67,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 946,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 3.35, 'deg': 281, 'gust': 5.9},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-19 00:00:00'},
#   {'dt': 1726714800,
#    'main': {'temp': 297.79,
#     'feels_like': 297.9,
#     'temp_min': 297.79,
#     'temp_max': 297.79,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 947,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.95, 'deg': 281, 'gust': 3.18},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-19 03:00:00'},
#   {'dt': 1726725600,
#    'main': {'temp': 302.59,
#     'feels_like': 302.42,
#     'temp_min': 302.59,
#     'temp_max': 302.59,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 946,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 11},
#    'wind': {'speed': 2.23, 'deg': 310, 'gust': 1.77},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-19 06:00:00'},
#   {'dt': 1726736400,
#    'main': {'temp': 305.72,
#     'feels_like': 304.76,
#     'temp_min': 305.72,
#     'temp_max': 305.72,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 943,
#     'humidity': 31,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.79, 'deg': 304, 'gust': 2.19},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-19 09:00:00'},
#   {'dt': 1726747200,
#    'main': {'temp': 304.7,
#     'feels_like': 303.93,
#     'temp_min': 304.7,
#     'temp_max': 304.7,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 943,
#     'humidity': 34,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 45},
#    'wind': {'speed': 4.07, 'deg': 332, 'gust': 3.49},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-19 12:00:00'},
#   {'dt': 1726758000,
#    'main': {'temp': 299.67,
#     'feels_like': 299.67,
#     'temp_min': 299.67,
#     'temp_max': 299.67,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 946,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 76},
#    'wind': {'speed': 6.8, 'deg': 314, 'gust': 7.48},
#    'visibility': 10000,
#    'pop': 0.62,
#    'rain': {'3h': 0.47},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-19 15:00:00'},
#   {'dt': 1726768800,
#    'main': {'temp': 298.1,
#     'feels_like': 298.4,
#     'temp_min': 298.1,
#     'temp_max': 298.1,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 946,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 62},
#    'wind': {'speed': 5.16, 'deg': 299, 'gust': 7.5},
#    'visibility': 10000,
#    'pop': 0.8,
#    'rain': {'3h': 0.74},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-19 18:00:00'},
#   {'dt': 1726779600,
#    'main': {'temp': 297.27,
#     'feels_like': 297.64,
#     'temp_min': 297.27,
#     'temp_max': 297.27,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 945,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 80},
#    'wind': {'speed': 3.85, 'deg': 293, 'gust': 5.42},
#    'visibility': 10000,
#    'pop': 0.93,
#    'rain': {'3h': 1.14},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-19 21:00:00'},
#   {'dt': 1726790400,
#    'main': {'temp': 296.38,
#     'feels_like': 296.77,
#     'temp_min': 296.38,
#     'temp_max': 296.38,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 945,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 84},
#    'wind': {'speed': 3.63, 'deg': 291, 'gust': 5.66},
#    'visibility': 10000,
#    'pop': 0.86,
#    'rain': {'3h': 0.27},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-20 00:00:00'},
#   {'dt': 1726801200,
#    'main': {'temp': 298.2,
#     'feels_like': 298.46,
#     'temp_min': 298.2,
#     'temp_max': 298.2,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 947,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 87},
#    'wind': {'speed': 3.55, 'deg': 290, 'gust': 4.04},
#    'visibility': 10000,
#    'pop': 0.72,
#    'rain': {'3h': 0.49},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-20 03:00:00'},
#   {'dt': 1726812000,
#    'main': {'temp': 302.64,
#     'feels_like': 303.33,
#     'temp_min': 302.64,
#     'temp_max': 302.64,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 946,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 90},
#    'wind': {'speed': 4.01, 'deg': 311, 'gust': 3.6},
#    'visibility': 10000,
#    'pop': 0.09,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-20 06:00:00'},
#   {'dt': 1726822800,
#    'main': {'temp': 305.21,
#     'feels_like': 305.51,
#     'temp_min': 305.21,
#     'temp_max': 305.21,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 944,
#     'humidity': 40,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 86},
#    'wind': {'speed': 5.79, 'deg': 321, 'gust': 4.35},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-20 09:00:00'},
#   {'dt': 1726833600,
#    'main': {'temp': 303.59,
#     'feels_like': 304.06,
#     'temp_min': 303.59,
#     'temp_max': 303.59,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 944,
#     'humidity': 45,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 91},
#    'wind': {'speed': 6.9, 'deg': 310, 'gust': 5.55},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-20 12:00:00'},
#   {'dt': 1726844400,
#    'main': {'temp': 299.97,
#     'feels_like': 301.28,
#     'temp_min': 299.97,
#     'temp_max': 299.97,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 946,
#     'humidity': 64,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 62},
#    'wind': {'speed': 6, 'deg': 299, 'gust': 7.59},
#    'visibility': 10000,
#    'pop': 0.74,
#    'rain': {'3h': 0.63},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-20 15:00:00'},
#   {'dt': 1726855200,
#    'main': {'temp': 298.26,
#     'feels_like': 298.71,
#     'temp_min': 298.26,
#     'temp_max': 298.26,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 946,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 77},
#    'wind': {'speed': 6.13, 'deg': 297, 'gust': 8.36},
#    'visibility': 10000,
#    'pop': 0.68,
#    'rain': {'3h': 0.35},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-20 18:00:00'},
#   {'dt': 1726866000,
#    'main': {'temp': 296.97,
#     'feels_like': 297.44,
#     'temp_min': 296.97,
#     'temp_max': 296.97,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 945,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 4.76, 'deg': 293, 'gust': 6.98},
#    'visibility': 10000,
#    'pop': 0.51,
#    'rain': {'3h': 0.4},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-20 21:00:00'},
#   {'dt': 1726876800,
#    'main': {'temp': 296.32,
#     'feels_like': 296.78,
#     'temp_min': 296.32,
#     'temp_max': 296.32,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 945,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 3.92, 'deg': 280, 'gust': 6.38},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-21 00:00:00'},
#   {'dt': 1726887600,
#    'main': {'temp': 298.41,
#     'feels_like': 298.79,
#     'temp_min': 298.41,
#     'temp_max': 298.41,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 948,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 4.62, 'deg': 301, 'gust': 5.05},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-21 03:00:00'},
#   {'dt': 1726898400,
#    'main': {'temp': 302.42,
#     'feels_like': 303.72,
#     'temp_min': 302.42,
#     'temp_max': 302.42,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 947,
#     'humidity': 54,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 84},
#    'wind': {'speed': 3.51, 'deg': 319, 'gust': 3.57},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.39},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-21 06:00:00'},
#   {'dt': 1726909200,
#    'main': {'temp': 302.71,
#     'feels_like': 303.71,
#     'temp_min': 302.71,
#     'temp_max': 302.71,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 944,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 4.37, 'deg': 304, 'gust': 4.54},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.69},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-21 09:00:00'},
#   {'dt': 1726920000,
#    'main': {'temp': 297.98,
#     'feels_like': 298.58,
#     'temp_min': 297.98,
#     'temp_max': 297.98,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 944,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 4.48, 'deg': 321, 'gust': 6.91},
#    'visibility': 6443,
#    'pop': 1,
#    'rain': {'3h': 8.21},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-21 12:00:00'},
#   {'dt': 1726930800,
#    'main': {'temp': 296.35,
#     'feels_like': 297.02,
#     'temp_min': 296.35,
#     'temp_max': 296.35,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 947,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.18, 'deg': 306, 'gust': 7.7},
#    'visibility': 7285,
#    'pop': 1,
#    'rain': {'3h': 9.59},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-21 15:00:00'},
#   {'dt': 1726941600,
#    'main': {'temp': 296.32,
#     'feels_like': 296.96,
#     'temp_min': 296.32,
#     'temp_max': 296.32,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 947,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.53, 'deg': 275, 'gust': 7.68},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 2.89},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-21 18:00:00'},
#   {'dt': 1726952400,
#    'main': {'temp': 295.89,
#     'feels_like': 296.54,
#     'temp_min': 295.89,
#     'temp_max': 295.89,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 945,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.59, 'deg': 293, 'gust': 7.6},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.73},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-21 21:00:00'},
#   {'dt': 1726963200,
#    'main': {'temp': 296.09,
#     'feels_like': 296.74,
#     'temp_min': 296.09,
#     'temp_max': 296.09,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 945,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 3.17, 'deg': 284, 'gust': 5.91},
#    'visibility': 10000,
#    'pop': 0.8,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-09-22 00:00:00'},
#   {'dt': 1726974000,
#    'main': {'temp': 297.28,
#     'feels_like': 297.84,
#     'temp_min': 297.28,
#     'temp_max': 297.28,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 947,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.98, 'deg': 311, 'gust': 6.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-22 03:00:00'},
#   {'dt': 1726984800,
#    'main': {'temp': 301.2,
#     'feels_like': 303.02,
#     'temp_min': 301.2,
#     'temp_max': 301.2,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 946,
#     'humidity': 63,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 91},
#    'wind': {'speed': 4.49, 'deg': 324, 'gust': 4.8},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.12},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-22 06:00:00'},
#   {'dt': 1726995600,
#    'main': {'temp': 303.52,
#     'feels_like': 305.29,
#     'temp_min': 303.52,
#     'temp_max': 303.52,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 943,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 4.24, 'deg': 328, 'gust': 4.72},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.6},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-22 09:00:00'},
#   {'dt': 1727006400,
#    'main': {'temp': 299.2,
#     'feels_like': 299.2,
#     'temp_min': 299.2,
#     'temp_max': 299.2,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 943,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 5.94, 'deg': 309, 'gust': 8.5},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.98},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-22 12:00:00'}],
#  'city': {'id': 1277091,
#   'name': 'Bārāmati',
#   'coord': {'lat': 18.1841, 'lon': 74.6108},
#   'country': 'IN',
#   'population': 53919,
#   'timezone': 19800,
#   'sunrise': 1726534186,
#   'sunset': 1726578148}}

# %%
len(weather_data['list'])
# Out:
# 40

# %%
weather_data['list'][0]['weather'][0]['description']
# Out:
# 'broken clouds'

# %%
temperatures = [item['main']['temp'] for item in weather_data['list']]
timestamps = [pd.to_datetime(item['dt'], unit='s') for item in weather_data['list']]
temperature = [item['main']['temp'] for item in weather_data['list']]
humidity = [item['main']['humidity'] for item in weather_data['list']]
wind_speed = [item['wind']['speed'] for item in weather_data['list']]
weather_description = [item['weather'][0]['description'] for item in weather_data['list']]
# Create a pandas DataFrame with the extracted weather data
weather_df = pd.DataFrame({
'Timestamp': timestamps,
'Temperature': temperatures,
'humidity': humidity,
'wind_speed': wind_speed,
'weather_description': weather_description,
})
# Set the Timestamp column as the DataFrame's index
weather_df.set_index('Timestamp', inplace=True)
max_temp = weather_df['Temperature'].max()
max_temp
# Out:
# np.float64(305.72)

# %%
min_temp = weather_df['Temperature'].min()
min_temp
# Out:
# np.float64(294.48)

# %%
# Handling missing values
weather_df.fillna(0, inplace=True) # Replace missing values with 0 or appropriate value
# Handling inconsistent format (if applicable)
weather_df['Temperature'] = weather_df['Temperature'].apply(lambda x: x - 273.15 if isinstance(x, float)else x)

# %%
print(weather_df)
# Out:
#                      Temperature  humidity  wind_speed weather_description
# Timestamp
# 2024-09-17 15:00:00        28.32        43        7.68       broken clouds
# 2024-09-17 18:00:00        25.58        58        5.92       broken clouds
# 2024-09-17 21:00:00        22.33        74        4.11     overcast clouds
# 2024-09-18 00:00:00        21.33        78        3.32     overcast clouds
# 2024-09-18 03:00:00        24.10        63        4.29    scattered clouds
# 2024-09-18 06:00:00        29.03        37        2.73    scattered clouds
# 2024-09-18 09:00:00        31.72        29        3.48           clear sky
# 2024-09-18 12:00:00        31.21        29        5.76           clear sky
# 2024-09-18 15:00:00        25.83        61        7.00           clear sky
# 2024-09-18 18:00:00        23.70        72        4.51           clear sky
# 2024-09-18 21:00:00        22.29        78        3.73           clear sky
# 2024-09-19 00:00:00        21.52        80        3.35           clear sky
# 2024-09-19 03:00:00        24.64        61        2.95           clear sky
# 2024-09-19 06:00:00        29.44        42        2.23          few clouds
# 2024-09-19 09:00:00        32.57        31        2.79           clear sky
# 2024-09-19 12:00:00        31.55        34        4.07    scattered clouds
# 2024-09-19 15:00:00        26.52        62        6.80          light rain
# 2024-09-19 18:00:00        24.95        67        5.16          light rain
# 2024-09-19 21:00:00        24.12        73        3.85          light rain
# 2024-09-20 00:00:00        23.23        77        3.63          light rain
# 2024-09-20 03:00:00        25.05        65        3.55          light rain
# 2024-09-20 06:00:00        29.49        49        4.01     overcast clouds
# 2024-09-20 09:00:00        32.06        40        5.79     overcast clouds
# 2024-09-20 12:00:00        30.44        45        6.90     overcast clouds
# 2024-09-20 15:00:00        26.82        64        6.00          light rain
# 2024-09-20 18:00:00        25.11        72        6.13          light rain
# 2024-09-20 21:00:00        23.82        78        4.76          light rain
# 2024-09-21 00:00:00        23.17        80        3.92     overcast clouds
# 2024-09-21 03:00:00        25.26        69        4.62     overcast clouds
# 2024-09-21 06:00:00        29.27        54        3.51          light rain
# 2024-09-21 09:00:00        29.56        51        4.37          light rain
# 2024-09-21 12:00:00        24.83        79        4.48       moderate rain
# 2024-09-21 15:00:00        23.20        88        5.18       moderate rain
# 2024-09-21 18:00:00        23.17        87        4.53          light rain
# 2024-09-21 21:00:00        22.74        89        4.59          light rain
# 2024-09-22 00:00:00        22.94        88        3.17     overcast clouds
# 2024-09-22 03:00:00        24.13        80        4.98     overcast clouds
# 2024-09-22 06:00:00        28.05        63        4.49          light rain
# 2024-09-22 09:00:00        30.37        53        4.24          light rain
# 2024-09-22 12:00:00        26.05        75        5.94          light rain
