# %% [markdown]
# # Assignment 5
#
# A. Implement Random Forest Classifier model to predict the safety of the car. Dataset
# link: https://www.kaggle.com/datasets/elikplim/car-evaluation-data-set

# %%
! pip instal pandas
# Out:
# ERROR: unknown command "instal" - maybe you meant "install"

# %%
import pandas as pd

# %%
df=pd.read_csv('car_evaluation.csv')

# %%
df.head(2)
# Out:
#    vhigh vhigh.1  2 2.1  small   low  unacc
# 0  vhigh   vhigh  2   2  small   med  unacc
# 1  vhigh   vhigh  2   2  small  high  unacc

# %%
df.describe()
# Out:
#        vhigh vhigh.1     2   2.1 small   low  unacc
# count   1727    1727  1727  1727  1727  1727   1727
# unique     4       4     4     3     3     3      4
# top     high    high     3     4   med   med  unacc
# freq     432     432   432   576   576   576   1209

# %%
col_names = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']

df.columns=col_names
col_names
# Out:
# ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']

# %%
for col in col_names:
    print(df[col].value_counts())
# Out:
# buying
# high     432
# med      432
# low      432
# vhigh    431
# Name: count, dtype: int64
# maint
# high     432
# med      432
# low      432
# vhigh    431
# Name: count, dtype: int64
# doors
# 3        432
# 4        432
# 5more    432
# 2        431
# Name: count, dtype: int64
# persons
# 4       576
# more    576
# 2       575
# Name: count, dtype: int64
# lug_boot
# med      576
# big      576
# small    575
# Name: count, dtype: int64
# safety
# med     576
# high    576
# low     575
# Name: count, dtype: int64
# class
# unacc    1209
# acc       384
# good       69
# vgood      65
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# buying      0
# maint       0
# doors       0
# persons     0
# lug_boot    0
# safety      0
# class       0
# dtype: int64

# %%
x=df.drop(['class'],axis=1)
y=df['class']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((1208, 6), (519, 6))

# %%
pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.6.3-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: numpy>=1.14.0 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from category_encoders) (2.1.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from category_encoders) (1.5.2)
# Requirement already satisfied: scipy>=1.0.0 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from category_encoders) (1.14.1)
# Collecting statsmodels>=0.9.0 (from category_encoders)
#   Downloading statsmodels-0.14.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: pandas>=1.0.5 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from category_encoders) (2.2.2)
# Collecting patsy>=0.5.1 (from category_encoders)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from pandas>=1.0.5->category_encoders) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from pandas>=1.0.5->category_encoders) (2024.1)
# Requirement already satisfied: six in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from scikit-learn>=0.20.0->category_encoders) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from scikit-learn>=0.20.0->category_encoders) (3.5.0)
# Requirement already satisfied: packaging>=21.3 in /home/atharv/Downloads/practicals/.main-env/lib/python3.12/site-packages (from statsmodels>=0.9.0->category_encoders) (24.1)
# Downloading category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Downloading statsmodels-0.14.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 6.4 MB/s eta 0:00:0000:010:01
# Installing collected packages: patsy, statsmodels, category_encoders
# Successfully installed category_encoders-2.6.3 patsy-0.5.6 statsmodels-0.14.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import category_encoders as ce

encoder = ce.OrdinalEncoder(cols=['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety'])
x_train = encoder.fit_transform(x_train)
x_test = encoder.transform(x_test)

# %%
x_train.head()
# Out:
#       buying  maint  doors  persons  lug_boot  safety
# 1177       1      1      1        1         1       1
# 585        2      2      2        2         2       2
# 1551       3      1      2        1         3       2
# 727        2      1      3        2         1       1
# 707        2      1      3        3         1       3

# %%
from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier(random_state=0)

rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
y_pred=rfc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.928709055876686

# %%
rfc_100 = RandomForestClassifier(n_estimators=100, random_state=0)
rfc_100.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
y_pred_100=rfc_100.predict(x_test)
accuracy_score(y_test,y_pred_100)
# Out:
# 0.928709055876686

# %%
from sklearn.ensemble import RandomForestClassifier
rfc_100=RandomForestClassifier(n_estimators=100,random_state=0)
rfc_100.fit(x_train,y_train)
y_pred_100 = rfc_100.predict(x_test)
print("model accuracy n_estimator=100: {0:0.4f}".format(accuracy_score(y_test,y_pred_100)))
# Out:
# model accuracy n_estimator=100: 0.9287

# %%
print(y_train)
# Out:
# 1177    vgood
# 585     unacc
# 1551      acc
# 727       acc
# 707     unacc
#         ...
# 1130    unacc
# 1294    vgood
# 860     unacc
# 1459    unacc
# 1126      acc
# Name: class, Length: 1208, dtype: object
