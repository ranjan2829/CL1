# %% [markdown]
# Analyzing Weather Data from OpenWeatherMap API

# %%
import requests
import pandas as pd
import datetime
# Set your OpenWeatherMap API key
api_key = 'fb365aa6104829b44455572365ff3b4e'

# %%
lat = 18.184135
lon = 74.610764
#https://openweathermap.org/api/one-call-3#how How to use api call
# Construct the API URL
api_url = f"http://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={api_key}"
# Send a GET request to the API
response = requests.get(api_url)
weather_data = response.json() #pass response to weather_data object(dictionary)
weather_data
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1730743200,
#    'main': {'temp': 297.5,
#     'feels_like': 297.27,
#     'temp_min': 297.5,
#     'temp_max': 297.5,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 950,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 69},
#    'wind': {'speed': 3.3, 'deg': 103, 'gust': 6.56},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-04 18:00:00'},
#   {'dt': 1730754000,
#    'main': {'temp': 296.95,
#     'feels_like': 296.69,
#     'temp_min': 295.84,
#     'temp_max': 296.95,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 949,
#     'humidity': 50,
#     'temp_kf': 1.11},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 51},
#    'wind': {'speed': 2.92, 'deg': 148, 'gust': 2.87},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-04 21:00:00'},
#   {'dt': 1730764800,
#    'main': {'temp': 295.37,
#     'feels_like': 295.08,
#     'temp_min': 294.3,
#     'temp_max': 295.37,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 950,
#     'humidity': 55,
#     'temp_kf': 1.07},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 30},
#    'wind': {'speed': 2.02, 'deg': 113, 'gust': 2.09},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-05 00:00:00'},
#   {'dt': 1730775600,
#    'main': {'temp': 297.67,
#     'feels_like': 297.48,
#     'temp_min': 297.67,
#     'temp_max': 297.67,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 952,
#     'humidity': 50,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 2.54, 'deg': 117, 'gust': 3.43},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-05 03:00:00'},
#   {'dt': 1730786400,
#    'main': {'temp': 302.52,
#     'feels_like': 301.86,
#     'temp_min': 302.52,
#     'temp_max': 302.52,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.97, 'deg': 101, 'gust': 4.73},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-05 06:00:00'},
#   {'dt': 1730797200,
#    'main': {'temp': 304.23,
#     'feels_like': 302.88,
#     'temp_min': 304.23,
#     'temp_max': 304.23,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 948,
#     'humidity': 29,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.41, 'deg': 88, 'gust': 3.98},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-05 09:00:00'},
#   {'dt': 1730808000,
#    'main': {'temp': 302.7,
#     'feels_like': 301.87,
#     'temp_min': 302.7,
#     'temp_max': 302.7,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 948,
#     'humidity': 35,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 2.2, 'deg': 80, 'gust': 2.27},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-05 12:00:00'},
#   {'dt': 1730818800,
#    'main': {'temp': 299.59,
#     'feels_like': 299.59,
#     'temp_min': 299.59,
#     'temp_max': 299.59,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 950,
#     'humidity': 40,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 20},
#    'wind': {'speed': 2.83, 'deg': 61, 'gust': 3.03},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-05 15:00:00'},
#   {'dt': 1730829600,
#    'main': {'temp': 296.77,
#     'feels_like': 296.52,
#     'temp_min': 296.77,
#     'temp_max': 296.77,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 13},
#    'wind': {'speed': 3.3, 'deg': 137, 'gust': 3.75},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-05 18:00:00'},
#   {'dt': 1730840400,
#    'main': {'temp': 295.15,
#     'feels_like': 294.87,
#     'temp_min': 295.15,
#     'temp_max': 295.15,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 950,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.85, 'deg': 119, 'gust': 2.11},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-05 21:00:00'},
#   {'dt': 1730851200,
#    'main': {'temp': 294.1,
#     'feels_like': 293.82,
#     'temp_min': 294.1,
#     'temp_max': 294.1,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 1.81, 'deg': 117, 'gust': 1.81},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-06 00:00:00'},
#   {'dt': 1730862000,
#    'main': {'temp': 297.73,
#     'feels_like': 297.5,
#     'temp_min': 297.73,
#     'temp_max': 297.73,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 953,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 1.21, 'deg': 136, 'gust': 1.48},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-06 03:00:00'},
#   {'dt': 1730872800,
#    'main': {'temp': 302.07,
#     'feels_like': 301.43,
#     'temp_min': 302.07,
#     'temp_max': 302.07,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 952,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 1.7, 'deg': 50, 'gust': 2.99},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-06 06:00:00'},
#   {'dt': 1730883600,
#    'main': {'temp': 304.44,
#     'feels_like': 303,
#     'temp_min': 304.44,
#     'temp_max': 304.44,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 949,
#     'humidity': 28,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 3.13, 'deg': 25, 'gust': 3.91},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-06 09:00:00'},
#   {'dt': 1730894400,
#    'main': {'temp': 303.05,
#     'feels_like': 301.88,
#     'temp_min': 303.05,
#     'temp_max': 303.05,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 949,
#     'humidity': 31,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 5},
#    'wind': {'speed': 2.78, 'deg': 26, 'gust': 2.89},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-06 12:00:00'},
#   {'dt': 1730905200,
#    'main': {'temp': 298.95,
#     'feels_like': 298.53,
#     'temp_min': 298.95,
#     'temp_max': 298.95,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 951,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 4.23, 'deg': 38, 'gust': 6.27},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-06 15:00:00'},
#   {'dt': 1730916000,
#    'main': {'temp': 296.41,
#     'feels_like': 295.97,
#     'temp_min': 296.41,
#     'temp_max': 296.41,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 45,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 3.72, 'deg': 41, 'gust': 8.07},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-06 18:00:00'},
#   {'dt': 1730926800,
#    'main': {'temp': 294.62,
#     'feels_like': 294.21,
#     'temp_min': 294.62,
#     'temp_max': 294.62,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 950,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 2.07, 'deg': 94, 'gust': 1.99},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-06 21:00:00'},
#   {'dt': 1730937600,
#    'main': {'temp': 293.26,
#     'feels_like': 292.89,
#     'temp_min': 293.26,
#     'temp_max': 293.26,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 950,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 1.42, 'deg': 94, 'gust': 1.54},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-07 00:00:00'},
#   {'dt': 1730948400,
#    'main': {'temp': 297.11,
#     'feels_like': 296.89,
#     'temp_min': 297.11,
#     'temp_max': 297.11,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 952,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 9},
#    'wind': {'speed': 1.43, 'deg': 98, 'gust': 1.82},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-07 03:00:00'},
#   {'dt': 1730959200,
#    'main': {'temp': 301.85,
#     'feels_like': 301.02,
#     'temp_min': 301.85,
#     'temp_max': 301.85,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 34,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 26},
#    'wind': {'speed': 2.62, 'deg': 70, 'gust': 3.84},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-07 06:00:00'},
#   {'dt': 1730970000,
#    'main': {'temp': 303.88,
#     'feels_like': 302.3,
#     'temp_min': 303.88,
#     'temp_max': 303.88,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 948,
#     'humidity': 26,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 18},
#    'wind': {'speed': 3.3, 'deg': 45, 'gust': 4.15},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-07 09:00:00'},
#   {'dt': 1730980800,
#    'main': {'temp': 302.14,
#     'feels_like': 301.14,
#     'temp_min': 302.14,
#     'temp_max': 302.14,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 948,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 12},
#    'wind': {'speed': 1.95, 'deg': 65, 'gust': 1.71},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-07 12:00:00'},
#   {'dt': 1730991600,
#    'main': {'temp': 298.04,
#     'feels_like': 297.58,
#     'temp_min': 298.04,
#     'temp_max': 298.04,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 38,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.89, 'deg': 45, 'gust': 5.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-07 15:00:00'},
#   {'dt': 1731002400,
#    'main': {'temp': 296.08,
#     'feels_like': 295.71,
#     'temp_min': 296.08,
#     'temp_max': 296.08,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 950,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.24, 'deg': 115, 'gust': 2.91},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-07 18:00:00'},
#   {'dt': 1731013200,
#    'main': {'temp': 294.24,
#     'feels_like': 293.87,
#     'temp_min': 294.24,
#     'temp_max': 294.24,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 949,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.92, 'deg': 62, 'gust': 1.99},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-07 21:00:00'},
#   {'dt': 1731024000,
#    'main': {'temp': 293.32,
#     'feels_like': 292.93,
#     'temp_min': 293.32,
#     'temp_max': 293.32,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 950,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.07, 'deg': 129, 'gust': 2.16},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-08 00:00:00'},
#   {'dt': 1731034800,
#    'main': {'temp': 296.86,
#     'feels_like': 296.57,
#     'temp_min': 296.86,
#     'temp_max': 296.86,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 952,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.65, 'deg': 137, 'gust': 3.42},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-08 03:00:00'},
#   {'dt': 1731045600,
#    'main': {'temp': 301.43,
#     'feels_like': 300.79,
#     'temp_min': 301.43,
#     'temp_max': 301.43,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.76, 'deg': 96, 'gust': 4.55},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-08 06:00:00'},
#   {'dt': 1731056400,
#    'main': {'temp': 303.31,
#     'feels_like': 301.98,
#     'temp_min': 303.31,
#     'temp_max': 303.31,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 948,
#     'humidity': 29,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.27, 'deg': 87, 'gust': 3.81},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-08 09:00:00'},
#   {'dt': 1731067200,
#    'main': {'temp': 301.71,
#     'feels_like': 300.9,
#     'temp_min': 301.71,
#     'temp_max': 301.71,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 948,
#     'humidity': 34,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.07, 'deg': 115, 'gust': 1.91},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-08 12:00:00'},
#   {'dt': 1731078000,
#    'main': {'temp': 297.57,
#     'feels_like': 297.14,
#     'temp_min': 297.57,
#     'temp_max': 297.57,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 951,
#     'humidity': 41,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.13, 'deg': 62, 'gust': 2.32},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-08 15:00:00'},
#   {'dt': 1731088800,
#    'main': {'temp': 295.9,
#     'feels_like': 295.46,
#     'temp_min': 295.9,
#     'temp_max': 295.9,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 47,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.32, 'deg': 88, 'gust': 3.52},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-08 18:00:00'},
#   {'dt': 1731099600,
#    'main': {'temp': 294.42,
#     'feels_like': 293.99,
#     'temp_min': 294.42,
#     'temp_max': 294.42,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 949,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.06, 'deg': 100, 'gust': 3.07},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-08 21:00:00'},
#   {'dt': 1731110400,
#    'main': {'temp': 293.38,
#     'feels_like': 292.95,
#     'temp_min': 293.38,
#     'temp_max': 293.38,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 950,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.7, 'deg': 117, 'gust': 2.77},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-09 00:00:00'},
#   {'dt': 1731121200,
#    'main': {'temp': 296.81,
#     'feels_like': 296.54,
#     'temp_min': 296.81,
#     'temp_max': 296.81,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 952,
#     'humidity': 50,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.18, 'deg': 116, 'gust': 4.33},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-09 03:00:00'},
#   {'dt': 1731132000,
#    'main': {'temp': 301.82,
#     'feels_like': 301.13,
#     'temp_min': 301.82,
#     'temp_max': 301.82,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.32, 'deg': 106, 'gust': 3.12},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-09 06:00:00'},
#   {'dt': 1731142800,
#    'main': {'temp': 303.67,
#     'feels_like': 302.25,
#     'temp_min': 303.67,
#     'temp_max': 303.67,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 948,
#     'humidity': 28,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.95, 'deg': 102, 'gust': 1.69},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-09 09:00:00'},
#   {'dt': 1731153600,
#    'main': {'temp': 302.04,
#     'feels_like': 301.18,
#     'temp_min': 302.04,
#     'temp_max': 302.04,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 949,
#     'humidity': 34,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.69, 'deg': 102, 'gust': 1.8},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-11-09 12:00:00'},
#   {'dt': 1731164400,
#    'main': {'temp': 298.24,
#     'feels_like': 297.82,
#     'temp_min': 298.24,
#     'temp_max': 298.24,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 39,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.47, 'deg': 84, 'gust': 1.14},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-11-09 15:00:00'}],
#  'city': {'id': 1277091,
#   'name': 'Bārāmati',
#   'coord': {'lat': 18.1841, 'lon': 74.6108},
#   'country': 'IN',
#   'population': 53919,
#   'timezone': 19800,
#   'sunrise': 1730682137,
#   'sunset': 1730723275}}

# %%
len(weather_data['list'])
# Out:
# 40

# %%
temperatures = [item['main']['temp'] for item in weather_data['list']]
timestamps = [pd.to_datetime(item['dt'], unit='s') for item in weather_data['list']]
temperature = [item['main']['temp'] for item in weather_data['list']]
humidity = [item['main']['humidity'] for item in weather_data['list']]
wind_speed = [item['wind']['speed'] for item in weather_data['list']]
weather_description = [item['weather'][0]['description'] for item in weather_data['list']]
# Create a pandas DataFrame with the extracted weather data
weather_df = pd.DataFrame({
'Timestamp': timestamps,
'Temperature': temperatures,
'humidity': humidity,
'wind_speed': wind_speed,
'weather_description': weather_description,
})
# Set the Timestamp column as the DataFrame's index
weather_df.set_index('Timestamp', inplace=True)
max_temp = weather_df['Temperature'].max()
max_temp
# Out:
# 304.44

# %%
min_temp = weather_df['Temperature'].min()
min_temp
# Out:
# 293.26

# %%
# Handling missing values
weather_df.fillna(0, inplace=True) # Replace missing values with 0 or appropriate value
# Handling inconsistent format (if applicable)
weather_df['Temperature'] = weather_df['Temperature'].apply(lambda x: x - 273.15 if isinstance(x, float)else x)

# %%
print(weather_df)
# Out:
#                      Temperature  humidity  wind_speed weather_description
# Timestamp
# 2024-11-04 18:00:00        24.35        49        3.30       broken clouds
# 2024-11-04 21:00:00        23.80        50        2.92       broken clouds
# 2024-11-05 00:00:00        22.22        55        2.02    scattered clouds
# 2024-11-05 03:00:00        24.52        50        2.54           clear sky
# 2024-11-05 06:00:00        29.37        37        3.97           clear sky
# 2024-11-05 09:00:00        31.08        29        3.41           clear sky
# 2024-11-05 12:00:00        29.55        35        2.20           clear sky
# 2024-11-05 15:00:00        26.44        40        2.83          few clouds
# 2024-11-05 18:00:00        23.62        51        3.30          few clouds
# 2024-11-05 21:00:00        22.00        56        1.85           clear sky
# 2024-11-06 00:00:00        20.95        60        1.81           clear sky
# 2024-11-06 03:00:00        24.58        48        1.21           clear sky
# 2024-11-06 06:00:00        28.92        37        1.70           clear sky
# 2024-11-06 09:00:00        31.29        28        3.13           clear sky
# 2024-11-06 12:00:00        29.90        31        2.78           clear sky
# 2024-11-06 15:00:00        25.80        36        4.23           clear sky
# 2024-11-06 18:00:00        23.26        45        3.72           clear sky
# 2024-11-06 21:00:00        21.47        53        2.07           clear sky
# 2024-11-07 00:00:00        20.11        60        1.42           clear sky
# 2024-11-07 03:00:00        23.96        51        1.43           clear sky
# 2024-11-07 06:00:00        28.70        34        2.62    scattered clouds
# 2024-11-07 09:00:00        30.73        26        3.30          few clouds
# 2024-11-07 12:00:00        28.99        32        1.95          few clouds
# 2024-11-07 15:00:00        24.89        38        3.89           clear sky
# 2024-11-07 18:00:00        22.93        49        3.24           clear sky
# 2024-11-07 21:00:00        21.09        56        1.92           clear sky
# 2024-11-08 00:00:00        20.17        59        2.07           clear sky
# 2024-11-08 03:00:00        23.71        49        2.65           clear sky
# 2024-11-08 06:00:00        28.28        36        3.76           clear sky
# 2024-11-08 09:00:00        30.16        29        3.27           clear sky
# 2024-11-08 12:00:00        28.56        34        2.07           clear sky
# 2024-11-08 15:00:00        24.42        41        2.13           clear sky
# 2024-11-08 18:00:00        22.75        47        3.32           clear sky
# 2024-11-08 21:00:00        21.27        53        3.06           clear sky
# 2024-11-09 00:00:00        20.23        57        2.70           clear sky
# 2024-11-09 03:00:00        23.66        50        3.18           clear sky
# 2024-11-09 06:00:00        28.67        36        3.32           clear sky
# 2024-11-09 09:00:00        30.52        28        1.95           clear sky
# 2024-11-09 12:00:00        28.89        34        1.69           clear sky
# 2024-11-09 15:00:00        25.09        39        1.47           clear sky

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(14, 7))
plt.plot(weather_df.index, weather_df['Temperature'], marker='o')
plt.title('Temperature Changes Over Time')
plt.xlabel('Time')
plt.ylabel('Temperature (°C)')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(14, 7))
plt.bar(weather_df.index, weather_df['humidity'], color='blue')
plt.title('Humidity Levels Over Time')
plt.xlabel('Time')
plt.ylabel('Humidity (%)')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(14, 7))
plt.plot(weather_df.index, weather_df['wind_speed'], color='orange')
plt.title('Wind Speed Variations Over Time')
plt.xlabel('Time')
plt.ylabel('Wind Speed (m/s)')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# data on daily and monthly levels

# %%
response = requests.get(api_url)
weather_data = response.json()

# Convert the JSON data into a DataFrame
df = pd.DataFrame(weather_data['list'])

# Convert the 'dt' column to datetime
df['dt'] = pd.to_datetime(df['dt'], unit='s')

# Extract relevant columns
df = df[['dt', 'main', 'weather', 'wind']]

# Normalize the main column
df_main = pd.json_normalize(df['main'])

# Normalize the weather column
df['weather'] = df['weather'].apply(lambda x: x[0])  # Take the first weather condition
df_weather = pd.json_normalize(df['weather'])

# Normalize the wind column
df_wind = pd.json_normalize(df['wind'])

# Combine the normalized data with the original DataFrame
df = df.join(df_main).join(df_weather[['description']]).join(df_wind)
df.drop(columns=['main', 'weather', 'wind'], inplace=True)

# Set the datetime as the index
df.set_index('dt', inplace=True)

# Daily aggregation
daily_summary = df.resample('D').agg({
    'temp': 'mean',
    'feels_like': 'mean',
    'temp_min': 'min',
    'temp_max': 'max',
    'humidity': 'mean',
    'speed': 'mean',  # Ensure 'speed' is now present
    'description': lambda x: x.mode()[0]  # Most common weather description
})

# Monthly aggregation
monthly_summary = df.resample('M').agg({
    'temp': 'mean',
    'feels_like': 'mean',
    'temp_min': 'min',
    'temp_max': 'max',
    'humidity': 'mean',
    'speed': 'mean',  # Ensure 'speed' is now present
    'description': lambda x: x.mode()[0]  # Most common weather description
})

# Output results
print("Daily Summary:")
print(daily_summary)

print("\nMonthly Summary:")
print(monthly_summary)
# Out:
# Daily Summary:
#                  temp  feels_like  temp_min  temp_max   humidity     speed  \
# dt
# 2024-11-04  296.46000   296.19000    295.46    296.66  51.500000  3.080000
# 2024-11-05  298.99750   298.41750    294.17    304.16  43.750000  2.856250
# 2024-11-06  298.73750   298.11875    293.90    304.24  42.500000  2.618750
# 2024-11-07  298.06625   297.41250    292.78    303.71  43.625000  2.343750
# 2024-11-08  298.02500   297.40375    292.97    303.35  43.000000  2.740000
# 2024-11-09  299.19500   298.47500    293.07    303.50  39.833333  2.076667
#
#               description
# dt
# 2024-11-04  broken clouds
# 2024-11-05      clear sky
# 2024-11-06      clear sky
# 2024-11-07      clear sky
# 2024-11-08      clear sky
# 2024-11-09      clear sky
#
# Monthly Summary:
#                 temp  feels_like  temp_min  temp_max  humidity    speed  \
# dt
# 2024-11-30  298.4675   297.85125    292.78    304.24    43.125  2.57725
#
#            description
# dt
# 2024-11-30   clear sky
